# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
import os
print(os.getcwd())
# Out:
# /Users/carlosastudillo/Spatial data 4543-5993 Astudillo/4545-5993-Spacial-Data/Assignments/01-Python_Foundations/03-Loops_and_Iteration/Lessons/03-File_Loops_and_With

# %%
import os
print(os.listdir())
# Out:
# ['_header.md', 'README.md', '03-File_Loops_and_With.ipynb', '_autogen.md', 'meta.yaml', 'sample.txt']

# %%
with open('sample.txt', 'w') as file:
    file.write("Arsenal\nMan City\nLiverpool\n")

with open('sample.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Arsenal
# Man City
# Liverpool

# %%
# 📝 Sample file read
with open('sample.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# Arsenal
# Man City
# Liverpool

# %%
# 🔍 Process each line
with open('sample.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['Arsenal']
# Parts: ['Man City']
# Parts: ['Liverpool']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
# Tip: use `len(line.split()) > 3` to check
with open('sample.txt', 'r') as f:
    for line in f:
        if len(line.split()) > 1:
            print(line.strip())
# Out:
# Man City
