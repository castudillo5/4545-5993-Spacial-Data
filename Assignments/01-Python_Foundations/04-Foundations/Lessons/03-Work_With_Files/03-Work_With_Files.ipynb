# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory

# %%
# %ls  # List files in the current directory

# %%
# %cd ..  # Change to parent directory
# %pwd

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# !git clone https://github.com/castudillo5/4545-5993-Spacial-Data.git
# Out:
# Cloning into '4545-5993-Spacial-Data'...
# remote: Enumerating objects: 1671, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (234/234), done.
# remote: Total 1671 (delta 64), reused 179 (delta 14), pack-reused 1405 (from 1)
# Receiving objects: 100% (1671/1671), 424.65 MiB | 6.27 MiB/s, done.
# Resolving deltas: 100% (1004/1004), done.
# Updating files: 100% (1322/1322), done.

# %%
# %cd /content/4545-5993-Spatial-Data/Assignments/03-Loops_and_Iteration/
# %ls
# Out:
# [Errno 2] No such file or directory: '/content/4545-5993-Spatial-Data/Assignments/03-Loops_and_Iteration/'
# /Users/carlosastudillo/Spatial data 4543-5993 Astudillo/4545-5993-Spacial-Data/Assignments/01-Python_Foundations/04-Foundations/Lessons/03-Work_With_Files
# 03-Work_With_Files.ipynb  README.md                 _header.md
# 4545-5993-Spacial-Data/   _autogen.md               meta.yaml
# /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents
# Out:
# 'Hello, Jupyter!\nThis is a text file.\n'

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
with open("me.txt","w") as f:
    f.write("Carlos Astudillo")

# %%
with open("me.txt","r") as f:
    contents = f.read()
contents
# Out:
# 'Carlos Astudillo'

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
import json

Courses = {"Courses": ["Calc 2", "data science", "Contemporary languages"]}

with open("courses.json", "w") as f:
    json.dump(Courses, f)

with open("courses.json", "r") as f:
    loaded = json.load(f)
loaded
# Out:
# {'Courses': ['Calc 2', 'data science', 'Contemporary languages']}

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
import csv

rows = [["Pets", "Charlie"], ["Hobbies", "Golf"],["Grades", "A"]]
with open("pets.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

with open("pets.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Pets', 'Charlie']
# ['Hobbies', 'Golf']
# ['Grades', 'A']

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.
