# %% [markdown]
# # 📊 04 - Data Input and Output
#
# Most of data science is about **loading data, exploring it, and saving results**.
# In this notebook you will learn:
# - Reading CSV files with Pandas
# - Inspecting DataFrames (`head`, `info`, `describe`)
# - Writing data back to CSV
# - Reading Excel files (if available)

# %% [markdown]
# ## 1. Reading CSV Files

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#      |████████████████████████████████| 349 kB 10.2 MB/s eta 0:00:01
# Collecting numpy>=1.22.4
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 11.2 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 10.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-2.0.2 pandas-2.3.3 pytz-2026.2 tzdata-2026.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# Create a small CSV for demo
data = """Name,Age,Score
Alice,23,90
Bob,25,85
Charlie,22,95
"""
with open("students.csv", "w") as f:
    f.write(data)

# Read CSV into DataFrame
df = pd.read_csv("students.csv")
df
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Create your own small CSV (3–5 rows) and read it into Pandas.

# %%
import pandas as pd

masters = """Name,Position,Score
McIlroy, 1st, -11
Rose, 2nd, -11
Reed, 3rd, -9
"""
with open("masters.csv", "w") as f:
    f.write(masters)

df = pd.read_csv("masters.csv")
df
# Out:
#       Name Position  Score
# 0  McIlroy      1st    -11
# 1     Rose      2nd    -11
# 2     Reed      3rd     -9

# %% [markdown]
# ## 2. Exploring DataFrames

# %%
# Look at the first rows
df.head()

# %%
# Info about columns and data types
df.info()

# %%
# Summary statistics
df.describe()

# %% [markdown]
# ✅ **Your Turn**: Use `.head()` to preview your dataset and `.describe()` to see basic statistics.

# %%
df.head()
# Out:
#       Name Position  Score
# 0  McIlroy      1st    -11
# 1     Rose      2nd    -11
# 2     Reed      3rd     -9

# %%
df.describe()
# Out:
#            Score
# count   3.000000
# mean  -10.333333
# std     1.154701
# min   -11.000000
# 25%   -11.000000
# 50%   -11.000000
# 75%   -10.000000
# max    -9.000000

# %% [markdown]
# ## 3. Writing CSV Files

# %%
# Save the DataFrame to a new CSV
df.to_csv("students_copy.csv", index=False)
# %ls *.csv

# %% [markdown]
# ✅ **Your Turn**: Save your DataFrame to a CSV file called `my_data.csv`.

# %%
# Save the DataFrame to a new CSV
df.to_csv("students_copy.csv", index=False)
# %ls *.csv
# Out:
# masters.csv        students.csv       students_copy.csv

# %%
df.to_csv("masters_copy.csv", index=False)
# %ls *.csv
# Out:
# masters.csv        masters_copy.csv   students.csv       students_copy.csv

# %% [markdown]
# ## 4. Reading Excel Files

# %%
# Optional: Requires 'openpyxl' installed
# Save to Excel
df.to_excel("students.xlsx", index=False)

# Read Excel file
pd.read_excel("students.xlsx")

# %% [markdown]
# ✅ **Your Turn**: Try saving your dataset to Excel and reading it back (if supported in your environment).

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 1.7 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
df.to_excel("masters.xlsx", index = False)
pd.read_excel("masters.xlsx")
# Out:
#       Name Position  Score
# 0  McIlroy      1st    -11
# 1     Rose      2nd    -11
# 2     Reed      3rd     -9

# %% [markdown]
# ---
# ### Summary
# - `pd.read_csv` loads data into a DataFrame.
# - Use `.head()`, `.info()`, `.describe()` to explore quickly.
# - `df.to_csv` and `df.to_excel` save results.
# - Pandas makes file I/O simple and reliable.
