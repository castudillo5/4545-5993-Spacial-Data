# %% [markdown]
# ## 03 — Map Controls
#
# So far we have added layers to a map by calling `m.add()`. Controls work the same way — they are widgets you attach to the map — but instead of drawing features, they add **UI elements**: layer toggles, a scale bar, a fullscreen button, a minimap.
#
# This lesson covers the controls you will use most often.

# %% [markdown]
# ## Layers vs Controls
#
# | `m.add(...)` argument | What it does |
# |---|---|
# | `GeoJSON(...)` | draws geographic features on the map |
# | `TileLayer(...)` | draws a background tileset |
# | `LayersControl(...)` | adds a toggle panel for named layers |
# | `ScaleControl(...)` | adds a distance scale bar |
# | `FullscreenControl(...)` | adds a fullscreen button |
# | `MiniMap(...)` | adds a small overview map in the corner |
#
# All of these go through the same `m.add()` call. The map does not distinguish — it just manages a list of things attached to it.

# %% [markdown]
# ## Setup
#
# Load the GeoJSON data from the previous lesson and split it by geometry type.

# %%
import json
from ipyleaflet import Map, GeoJSON

WICHITA_FALLS = (33.9137, -98.4934)

with open("data/wichita_falls.geojson") as f:
    all_features = json.load(f)["features"]

points   = [f for f in all_features if f["geometry"]["type"] == "Point"]
lines    = [f for f in all_features if f["geometry"]["type"] == "LineString"]
polygons = [f for f in all_features if f["geometry"]["type"] == "Polygon"]

def make_fc(features):
    return {"type": "FeatureCollection", "features": features}

# %% [markdown]
# ## LayersControl
#
# `LayersControl` adds a panel in the corner that lets users toggle layers on and off. For it to work, each layer needs a **`name`** — that name appears as the label in the toggle panel.

# %%
from ipyleaflet import Map, GeoJSON, LayersControl

m = Map(center=WICHITA_FALLS, zoom=12)

# Give each layer a name — this is what appears in the toggle panel
point_layer = GeoJSON(data=make_fc(points),   name="Points of Interest")
line_layer  = GeoJSON(data=make_fc(lines),    name="Routes")
poly_layer  = GeoJSON(data=make_fc(polygons), name="Park Boundary")

m.add(point_layer)
m.add(line_layer)
m.add(poly_layer)

# Add the control — it automatically picks up all named layers
m.add(LayersControl())

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Click the stacked-layers icon in the top-right to expand the panel. Each named layer has a checkbox — uncheck one to hide it.
#
# Layers added **without** a `name` do not appear in the toggle panel.

# %% [markdown]
# ## ScaleControl
#
# `ScaleControl` draws a scale bar that updates as you zoom. It shows both metric and imperial units by default.

# %%
from ipyleaflet import Map, ScaleControl

m = Map(center=WICHITA_FALLS, zoom=12)
m.add(ScaleControl(position="bottomleft"))
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# The `position` argument accepts `"topleft"`, `"topright"`, `"bottomleft"`, or `"bottomright"`. All controls support this argument.

# %% [markdown]
# ## FullscreenControl
#
# `FullscreenControl` adds a button that expands the map to fill the browser window — useful when inspecting dense data.

# %%
import ipyleaflet
print(ipyleaflet.__version__)
# Out:
# 0.20.0

# %%
import ipywidgets as widgets
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
from ipyleaflet import Map, GeoJSON, FullScreenControl
from IPython.display import display

# Define the center of the map
WICHITA_FALLS = (33.9137, -98.4934)

# Example function to create a GeoJSON FeatureCollection
def make_fc(features):
    return {"type": "FeatureCollection", "features": features}

# Example GeoJSON data
all_features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "Polygon",
            "coordinates": [
                [
                    [-98.5, 33.9],
                    [-98.4, 33.9],
                    [-98.4, 33.8],
                    [-98.5, 33.8],
                    [-98.5, 33.9]
                ]
            ]
        },
        "properties": {"name": "Example Polygon"}
    }
]

# Create the map
m = Map(center=WICHITA_FALLS, zoom=12)

# Add GeoJSON data to the map
m.add(GeoJSON(data=make_fc(all_features)))

# Add fullscreen control
m.add(FullScreenControl(position="topright"))

# Display the map
display(m)
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## MiniMap
#
# `MiniMap` places a small overview map in a corner. It stays zoomed out while you navigate the main map — useful for keeping track of where you are at high zoom levels.

# %%
# %pip install ipyleaflet --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipyleaflet in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.5.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.8.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (8.1.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (2026.3.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.16)
# Requirement already satisfied: jinja2>=3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: decorator in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.20.0)
# Requirement already satisfied: stack-data in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.15.0)
# Requirement already satisfied: exceptiongroup in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install ipyleaflet==0.17.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipyleaflet==0.17.4
#   Downloading ipyleaflet-0.17.4-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (8.1.8)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (2026.3.0)
# Requirement already satisfied: branca>=0.5.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.16)
# Requirement already satisfied: jinja2>=3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from branca>=0.5.0->ipyleaflet==0.17.4) (3.1.6)
# Requirement already satisfied: decorator in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (2.20.0)
# Requirement already satisfied: stack-data in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.15.0)
# Requirement already satisfied: exceptiongroup in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet==0.17.4) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.3)
# Downloading ipyleaflet-0.17.4-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 10.7 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: ipyleaflet
#   Attempting uninstall: ipyleaflet
#     Found existing installation: ipyleaflet 0.20.0
#     Uninstalling ipyleaflet-0.20.0:
#       Successfully uninstalled ipyleaflet-0.20.0
# Successfully installed ipyleaflet-0.17.4

# %%
import ipyleaflet
print(ipyleaflet.__version__)
print(ipyleaflet.__file__)
# Out:
# 0.17.4
# /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages/ipyleaflet/__init__.py

# %%
import ipyleaflet
print(dir(ipyleaflet))
# Out:
# ['AntPath', 'Any', 'AttributionControl', 'AwesomeIcon', 'Bool', 'Box', 'CFloat', 'CallbackDispatcher', 'Choropleth', 'Circle', 'CircleMarker', 'Color', 'ColorMap', 'ColormapControl', 'Control', 'ControlException', 'DOMWidget', 'Dict', 'DivIcon', 'DrawControl', 'EXTENSION_VERSION', 'Enum', 'FeatureGroup', 'Float', 'FullScreenControl', 'GeoData', 'GeoJSON', 'Heatmap', 'Icon', 'ImageOverlay', 'ImageService', 'Instance', 'InstanceDict', 'Int', 'InteractMixin', 'Layer', 'LayerException', 'LayerGroup', 'LayersControl', 'LegendControl', 'List', 'LocalTileLayer', 'MagnifyingGlass', 'Map', 'MapStyle', 'Marker', 'MarkerCluster', 'MeasureControl', 'Output', 'PaneException', 'Path', 'Polygon', 'Polyline', 'Popup', 'RasterLayer', 'Rectangle', 'ScaleControl', 'SearchControl', 'SplitMapControl', 'Style', 'TileLayer', 'TraitError', 'Tuple', 'UILayer', 'Unicode', 'Union', 'VectorLayer', 'VectorTileLayer', 'VideoOverlay', 'WKTLayer', 'WMSLayer', 'Widget', 'WidgetControl', 'ZoomControl', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_jupyter_labextension_paths', '_jupyter_nbextension_paths', '_version', 'allowed_cursor', 'asyncio', 'basemap_to_tiles', 'basemaps', 'copy', 'date', 'def_loc', 'default', 'display', 'embed_minimal_html', 'interactive', 'isnan', 'json', 'leaflet', 'linear', 'link', 'observe', 'projections', 'sys', 'timedelta', 'validate', 'version_info', 'wait_for_change', 'warnings', 'widget_serialization', 'xyzservices', 'yesterday']

# %%
from ipyleaflet import Map, SplitMapControl, TileLayer

# Define the center of the map
WICHITA_FALLS = (33.9137, -98.4934)

# Create the map
m = Map(center=WICHITA_FALLS, zoom=13)

# Add the SplitMapControl
m.add(SplitMapControl(left_layer=TileLayer(), right_layer=TileLayer()))

# Display the map
display(m)
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Putting It Together
#
# Controls compose — you can add as many as you need to a single map.

# %%
# %pip install ipyleaflet==0.17.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipyleaflet==0.17.4 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (0.17.4)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (8.1.8)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (2026.3.0)
# Requirement already satisfied: branca>=0.5.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet==0.17.4) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.16)
# Requirement already satisfied: jinja2>=3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from branca>=0.5.0->ipyleaflet==0.17.4) (3.1.6)
# Requirement already satisfied: decorator in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (2.20.0)
# Requirement already satisfied: stack-data in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.15.0)
# Requirement already satisfied: exceptiongroup in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet==0.17.4) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet==0.17.4) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipyleaflet --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipyleaflet in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (0.17.4)
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: branca>=0.5.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.8.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (8.1.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipyleaflet) (2026.3.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.16)
# Requirement already satisfied: jinja2>=3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: decorator in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.20.0)
# Requirement already satisfied: stack-data in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.15.0)
# Requirement already satisfied: exceptiongroup in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Installing collected packages: ipyleaflet
#   Attempting uninstall: ipyleaflet
#     Found existing installation: ipyleaflet 0.17.4
#     Uninstalling ipyleaflet-0.17.4:
#       Successfully uninstalled ipyleaflet-0.17.4
# Successfully installed ipyleaflet-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

# Ensure the variable 'all_features' is defined
with open("data/wichita_falls.geojson") as f:
    all_features = json.load(f)["features"]

# Ensure the variable 'points' is defined
points = [f for f in all_features if f["geometry"]["type"] == "Point"]

# %% [markdown]
# ## Exercise A
#
# Rebuild the "Putting It Together" map using `basemaps.Esri.WorldImagery` (satellite tiles) instead of the default street map. Keep all three named layers and all four controls.

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullScreenControl, MiniMap

# Rebuild the composite map — polygon layer starts hidden (visible=False)
m = Map(center=WICHITA_FALLS, zoom=12)

poly_layer = GeoJSON(data=make_fc(polygons), name="Park Boundary", visible=False)

# Add the remaining layers and all four controls
# Your code here

m
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullScreenControl, MiniMap  # Added MiniMap import
#       3 # Ensure all_features is defined
#       4 with open("data/wichita_falls.geojson") as f:  # Ensure the file path is correct
#
# ImportError: cannot import name 'MiniMap' from 'ipyleaflet' (/Users/carlosastudillo/Library/Python/3.9/lib/python/site-packages/ipyleaflet/__init__.py)

# %% [markdown]
# ## Exercise B
#
# ipyleaflet layers have a `visible` attribute you can set at any time — the map updates live without re-rendering.
#
# 1. Rebuild the composite map with the polygon layer starting **hidden** (`visible=False`)
# 2. Display the map — confirm the polygon layer is absent
# 3. In a new cell, set `poly_layer.visible = True` and watch the map update in place

# %%
from ipyleaflet import Map, GeoJSON, LayersControl, ScaleControl, FullscreenControl, MiniMap, basemaps

m = Map(center=WICHITA_FALLS, zoom=12, basemap=basemaps.Esri.WorldImagery)

# Add the three named layers and all four controls
# Your code here

m

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Build a map centered on Wichita Falls at zoom 12 with:
# - **two named GeoJSON layers** (points and polygons from `data/wichita_falls.geojson`)
# - a `LayersControl` so both can be toggled
# - a `ScaleControl` in the bottom-right corner
#
# ```python
# # your answer here
# ```

# %% [markdown]
# ## Next
#
# In [03 — Attributes, Styling, and Filtering](../03-Attributes_Styling_Filtering/00-Properties.ipynb), we start reading feature properties and using them to style layers dynamically.
