# %% [markdown]
# ## 00 — Map Events
#
# Every map we have built so far has been **static from Python's perspective** — you run the cell, the map appears, and Python is done. The user can pan and zoom, but nothing feeds back into your code.
#
# This lesson changes that. ipyleaflet maps generate **events** — structured messages sent to Python every time the user does something. You write a function that receives those messages and responds to them.
#
# ```
# Static map    →  user sees map
# Interactive map  →  user asks map questions  →  Python responds
# ```

# %% [markdown]
# ## What Is an Interactive Map?
#
# You already know what interactive maps feel like:
#
# - Clicking a location on Google Maps drops a pin and shows its address
# - Clicking a country on a news graphic shows a popup with data
# - Drawing a route measures the total distance
#
# In every case, **a user action triggered a response**. The map noticed where you clicked and did something with that information.
#
# In ipyleaflet, *you* write the response. The map tells you what happened; your Python function decides what to do with it.

# %% [markdown]
# ## The ipyleaflet Event System
#
# ipyleaflet uses an **observer pattern**:
#
# 1. You write a handler function
# 2. You register it with the map using `m.on_interaction(handler)`
# 3. Every time the user interacts with the map, ipyleaflet calls your handler with a dict of event data
#
# ```
# user action  →  ipyleaflet  →  your handler function  →  your response
# ```
#
# The handler always has the same signature: it accepts `**kwargs`.

# %%
from ipyleaflet import Map

WICHITA_FALLS = (33.9137, -98.4934)

m = Map(center=WICHITA_FALLS, zoom=12)

# This handler prints every piece of data the event sends
def handle_interaction(**kwargs):
    print(kwargs)

m.on_interaction(handle_interaction)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…
# {'event': 'interaction', 'type': 'mouseover', 'coordinates': [33.970697997361626, -98.64486694335939]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.970697997361626, -98.64486694335939]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.96955908729964, -98.64383697509767]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.96813542827284, -98.64315032958986]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.96443380326997, -98.64143371582033]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.962155800118985, -98.64349365234376]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.95845391488702, -98.64246368408205]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.956175751601826, -98.64177703857423]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.950764869326804, -98.64074707031251]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.947916898356404, -98.64040374755861]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.94620807002934, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.94392957889264, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.94421439362013, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.950195282757015, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.957030069982316, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.963579559237516, -98.63697052001955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.968420161984795, -98.63594055175781]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.970697997361626, -98.6355972290039]}
# {'event': 'interaction', 'type': 'mouseout', 'coordinates': [33.97439934971994, -98.6349105834961]}
# {'event': 'interaction', 'type': 'mouseover', 'coordinates': [33.857016635441404, -98.63147735595703]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.857016635441404, -98.63147735595703]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.85958254798477, -98.63044738769533]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.86214838343116, -98.6290740966797]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.86756489395595, -98.62598419189455]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.87013048952702, -98.62392425537111]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.87269600798948, -98.62186431884767]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.87953701355924, -98.61499786376955]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.882387270695126, -98.61087799072266]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.88666247787436, -98.60401153564455]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.888087499325636, -98.60195159912111]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.89122246272394, -98.59714508056642]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.89435731090067, -98.59233856201172]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.897777013859475, -98.58684539794923]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.89891688437142, -98.5847854614258]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90005673964575, -98.58272552490236]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.900911621101685, -98.58100891113283]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57997894287111]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57894897460939]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57860565185548]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57826232910158]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57826232910158]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57826232910158]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.90119657968227, -98.57826232910158]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33
}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.88381236355863, -98.59851837158205]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.88381236355863, -98.59851837158205]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.882672291172085, -98.59851837158205]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.880677127838844, -98.59748840332033]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.87953701355924, -98.59680175781251]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.877256739300186, -98.59542846679689]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.87469135792663, -98.59439849853517]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.86842010104708, -98.5916519165039]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.864714141777746, -98.5909652709961]}
# {'event': 'interaction', 'type': 'mousemove', 'coordinates': [33.863288729992746, -98.59062194824219]}
# {'event': 'interaction', 'type': 'mouseout', 'coordinates': [33.807964383611484, -98.59062194824219]}

# %% [markdown]
# Click anywhere on the map above. You will see a dict printed below the cell — that is the raw event payload.
#
# Notice that **every mouse movement** also fires an event. That is a lot of output. In the next section we will filter to only the events we care about.

# %% [markdown]
# ## The Event Data Structure
#
# Every event dict contains at least a `"type"` key. Click events also include `"coordinates"`. The full structure looks like this:
#
# ```python
# {
#     "type":        "click",          # event type string
#     "coordinates": [lat, lon],       # where the click landed
# }
# ```
#
# The `"type"` field tells you what kind of interaction occurred. The common types are:
#
# | `type` value | When it fires |
# |---|---|
# | `"click"` | single left-click |
# | `"dblclick"` | double-click |
# | `"mousemove"` | cursor moves across map |
# | `"mousedown"` | mouse button pressed |
# | `"mouseup"` | mouse button released |
# | `"contextmenu"` | right-click |
#
# Most of the time you only care about `"click"`. Filter by checking `kwargs["type"]` at the top of your handler.

# %%
from ipyleaflet import Map

m = Map(center=WICHITA_FALLS, zoom=12)

def handle_click(**kwargs):
    # Ignore everything except actual clicks
    if kwargs.get("type") != "click":
        return

    print(kwargs)  # inspect the full payload

m.on_interaction(handle_click)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Now only clicks produce output. Notice the `"coordinates"` key — it holds `[latitude, longitude]` in ipyleaflet order.

# %% [markdown]
# ## Extracting Coordinates
#
# Pull `lat` and `lon` out of the coordinates list.

# %%
from ipyleaflet import Map

m = Map(center=WICHITA_FALLS, zoom=12)

def handle_click(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    print(f"lat={lat:.5f}  lon={lon:.5f}")

m.on_interaction(handle_click)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## A Coordinate Logger
#
# Collecting clicked coordinates into a list turns the map into a **coordinate generator** — an extremely useful tool for building GeoJSON by hand, marking targets, or creating test data.
#
# Each click appends to `clicked_points`. The list grows as you click.

# %%
from ipyleaflet import Map

m = Map(center=WICHITA_FALLS, zoom=12)

clicked_points = []

def log_click(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    clicked_points.append((lat, lon))
    print(f"[{len(clicked_points)}]  lat={lat:.5f}  lon={lon:.5f}")

m.on_interaction(log_click)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…
# [1]  lat=33.88182  lon=-98.53741
# [2]  lat=33.87042  lon=-98.50616
# [3]  lat=33.89436  lon=-98.60847

# %%
# Inspect the collected points after clicking
print(f"{len(clicked_points)} points collected:")
for i, (lat, lon) in enumerate(clicked_points):
    print(f"  {i+1}.  ({lat:.5f}, {lon:.5f})")
# Out:
# 3 points collected:
#   1.  (33.88182, -98.53741)
#   2.  (33.87042, -98.50616)
#   3.  (33.89436, -98.60847)

# %% [markdown]
# ## Placing a Marker on Click
#
# The logger is useful on its own, but the real power is **changing the map in response to a click**. Here we drop a marker at every clicked location.

# %%
from ipyleaflet import Map, Marker

m = Map(center=WICHITA_FALLS, zoom=12)

def place_marker(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    marker = Marker(location=(lat, lon), title=f"{lat:.4f}, {lon:.4f}")
    m.add(marker)

m.on_interaction(place_marker)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Click several locations. Each click immediately adds a marker — no cell re-run needed. This is the widget model from Lesson 01 in action: the map is a live object, and `m.add()` updates it in place.

# %% [markdown]
# ## Exercise A
#
# Modify the click handler to only place a marker on **every other click** — odd-numbered clicks (1st, 3rd, 5th...) get a marker; even-numbered clicks are silently ignored. Print which clicks are skipped.

# %%
from ipyleaflet import Map, Marker
from IPython.display import display

m = Map(center=WICHITA_FALLS, zoom=12)
markers = []
click_count = [0]  # use a list so it can be modified inside the function

def handle_click(**kwargs):
    if kwargs.get("type") == "click":
        click_count[0] += 1
        if click_count[0] % 2 != 0:  # only odd clicks (1st, 3rd, 5th...)
            coords = kwargs.get("coordinates")
            marker = Marker(location=coords)
            markers.append(marker)
            m.add(marker)

m.on_interaction(handle_click)
display(m)
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Exercise B
#
# Extend your click handler to handle two event types:
#
# - **Single click** (`"click"`) — drops a default marker
# - **Double-click** (`"dblclick"`) — removes all markers from the map and prints `"Cleared"`
#
# Tip: check `kwargs.get("type")` for both values.

# %%
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

m = Map(center=WICHITA_FALLS, zoom=12)
markers = []

def handle_interaction(**kwargs):
    event = kwargs.get("type")
    
    if event == "click":
        coords = kwargs.get("coordinates")
        marker = Marker(location=coords)
        markers.append(marker)
        m.add(marker)
    
    elif event == "dblclick":
        for marker in markers:
            m.remove(marker)
        markers.clear()

m.on_interaction(handle_interaction)
display(m)
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Build a map that:
#
# 1. Drops a marker on every click
# 2. Prints the total number of markers placed after each click (e.g., `"3 markers placed"`)
#
# ```python
# # your answer here
# ```

# %%
from ipyleaflet import Map, Marker
from IPython.display import display

m = Map(center=WICHITA_FALLS, zoom=12)
markers = []

def handle_click(**kwargs):
    if kwargs.get("type") == "click":
        coords = kwargs.get("coordinates")
        marker = Marker(location=coords)
        markers.append(marker)
        m.add(marker)
        print(f"{len(markers)} markers placed")

m.on_interaction(handle_click)
display(m)
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Next
#
# In [01 — Click Interactions](./01-Click_Interactions.ipynb), we use click coordinates to build things — numbered markers, growing paths, and a GeoJSON export of everything collected.
